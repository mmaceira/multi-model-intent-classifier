# %% [markdown]
# # 05 – Results Comparison
# Aggregated view across all evaluated models.

# %%
# -------------------------------------------------------------
# Common pre‑amble – read config & export core variables
# -------------------------------------------------------------

from pathlib import Path
import os, sys

# infer repo root from the location of this file
repo_root = os.path.abspath('..')
sys.path.insert(0, str(repo_root))  # allow `import src.*`
from config.notebook_setup import *
# Out:
# Repository Root: /home/marcmaceira/projects/reuters-rag-classifier_clean
# Configuration: {'general': {'run_name': 'experiment_with_13_classes', 'seed': 42, 'n_classes': 13}, 'dataset': {'split_type': 'test', 'test_split': 0.2, 'cutoff_year': 1996}, 'paths': {'data_exploration_dir': 'experiment_with_13_classes/data_exploration', 'artifacts_dir': 'experiment_with_13_classes/artifacts', 'embeddings_dir': 'experiment_with_13_classes/embeddings', 'models_dir': 'experiment_with_13_classes/models', 'results_dir': 'experiment_with_13_classes/results'}, 'model': {'embedding_backend': 'sbert', 'sbert_model_name': 'sentence-transformers/all-MiniLM-L12-v2', 'openai_model_name': 'text-embedding-3-small', 'classifier': 'linear_svm', 'rag_top_k': 5, 'use_llm_refine': False}, 'training': {'batch_size': 32, 'max_epochs': 10, 'learning_rate': '1e-3'}, 'evaluation': {'metrics': ['accuracy', 'macro_f1', 'auc_ovr']}}
#
# === Configuration Variables ===
#
# [DATASET]
#   DATASET_CUTOFF_YEAR: 1996
#   DATASET_SPLIT_TYPE: test
#   DATASET_TEST_SPLIT: 0.2
#
# [EVALUATION]
#   EVALUATION_METRICS: ['accuracy', 'macro_f1', 'auc_ovr']
#
# [GENERAL]
#   GENERAL_N_CLASSES: 13
#   GENERAL_RUN_NAME: experiment_with_13_classes
#   GENERAL_SEED: 42
#
# [MODEL]
#   MODEL_CLASSIFIER: linear_svm
#   MODEL_EMBEDDING_BACKEND: sbert
#   MODEL_OPENAI_MODEL_NAME: text-embedding-3-small
#   MODEL_RAG_TOP_K: 5
#   MODEL_SBERT_MODEL_NAME: sentence-transformers/all-MiniLM-L12-v2
#   MODEL_USE_LLM_REFINE: False
#
# [PATHS]
#   PATHS_ARTIFACTS_DIR: /home/marcmaceira/projects/reuters-rag-classifier_clean/experiment_with_13_classes/artifacts
#   PATHS_DATA_EXPLORATION_DIR: /home/marcmaceira/projects/reuters-rag-classifier_clean/experiment_with_13_classes/data_exploration
#   PATHS_EMBEDDINGS_DIR: /home/marcmaceira/projects/reuters-rag-classifier_clean/experiment_with_13_classes/embeddings
#   PATHS_MODELS_DIR: /home/marcmaceira/projects/reuters-rag-classifier_clean/experiment_with_13_classes/models
#   PATHS_RESULTS_DIR: /home/marcmaceira/projects/reuters-rag-classifier_clean/experiment_with_13_classes/results
#
# [TRAINING]
#   TRAINING_BATCH_SIZE: 32
#   TRAINING_LEARNING_RATE: 1e-3
#   TRAINING_MAX_EPOCHS: 10
#
# === Environment Variables ===
# N_CLASSES: 13
#
# === Creating Directories ===
# Created directory: /home/marcmaceira/projects/reuters-rag-classifier_clean/experiment_with_13_classes/data_exploration
# Created directory: /home/marcmaceira/projects/reuters-rag-classifier_clean/experiment_with_13_classes/artifacts
# Created directory: /home/marcmaceira/projects/reuters-rag-classifier_clean/experiment_with_13_classes/embeddings
# Created directory: /home/marcmaceira/projects/reuters-rag-classifier_clean/experiment_with_13_classes/models
# Created directory: /home/marcmaceira/projects/reuters-rag-classifier_clean/experiment_with_13_classes/results

# %%
import pandas as pd
from pathlib import Path

# Print the current results directory to see what's being used
print(f"Results directory: {RESULTS_DIR}")

summary_path = Path(RESULTS_DIR) / "summary_metrics.csv"
print(f"Looking for file at: {summary_path}")

# Check if file exists
if not summary_path.exists():
    print(f"Error: File not found at {summary_path}")
    
    # Look at what's in the results directory
    print(f"\nContents of {RESULTS_DIR}:")
    for item in Path(RESULTS_DIR).iterdir():
        print(f"  - {item.name}")
        
else:
    summary = pd.read_csv(summary_path, index_col=0)

summary
# Out:
# Results directory: /home/marcmaceira/projects/reuters-rag-classifier_clean/experiment_with_13_classes/results
# Looking for file at: /home/marcmaceira/projects/reuters-rag-classifier_clean/experiment_with_13_classes/results/summary_metrics.csv
#                              test_accuracy  test_macro_f1  test_weighted_f1  \
# RAG-kMajority                     0.743590       0.735956          0.735956
# Naive Bayes                       0.705128       0.694865          0.694865
# RAG-LLM (OpenAI-embeddings)       0.743590       0.725185          0.725185
# MiniLM + LogReg                   0.807692       0.800328          0.800328
# RAG-CentroidNN                    0.782051       0.774323          0.774323
# RAG-LLM (local-embeddings)        0.692308       0.656098          0.656098
# TF-IDF bigrams + SVM              0.756410       0.738520          0.738520
# Linear SVM                        0.743590       0.731702          0.731702
#
#                              test_roc_auc  test_avg_precision  train_accuracy  \
# RAG-kMajority                    0.960025            0.812527        0.851648
# Naive Bayes                      0.974804            0.772027        1.000000
# RAG-LLM (OpenAI-embeddings)      0.954060            0.791022        0.758242
# MiniLM + LogReg                  0.983707            0.852862        0.961538
# RAG-CentroidNN                   0.985221            0.859539        0.950549
# RAG-LLM (local-embeddings)       0.960025            0.812527        0.697802
# TF-IDF bigrams + SVM             0.978454            0.806030        1.000000
# Linear SVM                       0.976318            0.797888        1.000000
#
#                              train_macro_f1  train_weighted_f1  accuracy_diff  \
# RAG-kMajority                      0.851133           0.851133       0.108059
# Naive Bayes                        1.000000           1.000000       0.294872
# RAG-LLM (OpenAI-embeddings)        0.737567           0.737567       0.014652
# MiniLM + LogReg                    0.961258           0.961258       0.153846
# RAG-CentroidNN                     0.950267           0.950267       0.168498
# RAG-LLM (local-embeddings)         0.669900           0.669900       0.005495
# TF-IDF bigrams + SVM               1.000000           1.000000       0.243590
# Linear SVM                         1.000000           1.000000       0.256410
#
#                              macro_f1_diff  train_roc_auc  \
# RAG-kMajority                     0.115177       0.992723
# Naive Bayes                       0.305135       1.000000
# RAG-LLM (OpenAI-embeddings)       0.012382       0.992543
# MiniLM + LogReg                   0.160930       0.999264
# RAG-CentroidNN                    0.175944       0.998528
# RAG-LLM (local-embeddings)        0.013802       0.992723
# TF-IDF bigrams + SVM              0.261480       1.000000
# Linear SVM                        0.268298       1.000000
#
#                              train_avg_precision  roc_auc_diff  \
# RAG-kMajority                           0.910550      0.032698
# Naive Bayes                             1.000000      0.025196
# RAG-LLM (OpenAI-embeddings)             0.906320      0.038483
# MiniLM + LogReg                         0.989901      0.015557
# RAG-CentroidNN                          0.984488      0.013307
# RAG-LLM (local-embeddings)              0.910550      0.032698
# TF-IDF bigrams + SVM                    1.000000      0.021546
# Linear SVM                              1.000000      0.023682
#
#                              test_accuracy_best  test_macro_f1_best  \
# RAG-kMajority                             False               False
# Naive Bayes                               False               False
# RAG-LLM (OpenAI-embeddings)               False               False
# MiniLM + LogReg                            True                True
# RAG-CentroidNN                            False               False
# RAG-LLM (local-embeddings)                False               False
# TF-IDF bigrams + SVM                      False               False
# Linear SVM                                False               False
#
#                              test_weighted_f1_best  test_roc_auc_best
# RAG-kMajority                                False              False
# Naive Bayes                                  False              False
# RAG-LLM (OpenAI-embeddings)                  False              False
# MiniLM + LogReg                               True              False
# RAG-CentroidNN                               False               True
# RAG-LLM (local-embeddings)                   False              False
# TF-IDF bigrams + SVM                         False              False
# Linear SVM                                   False              False
