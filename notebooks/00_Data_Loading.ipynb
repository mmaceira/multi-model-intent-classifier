# %%
# -------------------------------------------------------------
# Common pre‑amble – read config & export core variables
# -------------------------------------------------------------

from pathlib import Path
import os, sys

# infer repo root from the location of this file
repo_root = os.path.abspath('..')
sys.path.insert(0, str(repo_root))  # allow `import src.*`
from config.notebook_setup import *
# Out:
# Repository Root: /home/marcmaceira/projects/reuters-rag-classifier_clean_v2
# Configuration: {'general': {'run_name': 'experiment_with_05_classes', 'seed': 42}, 'dataset': {'split_type': 'test', 'n_classes': 25, 'n_samples_per_class': 100}, 'paths': {'data_exploration_dir': 'output/experiment_with_05_classes/data_exploration', 'embeddings_dir': 'output/experiment_with_05_classes/embeddings', 'models_dir': 'output/experiment_with_05_classes/models', 'results_dir': 'output/experiment_with_05_classes/results'}, 'model': {'embedding_backend': 'sbert', 'sbert_model_name': 'sentence-transformers/all-MiniLM-L12-v2', 'openai_model_name': 'text-embedding-3-small', 'classifier': 'linear_svm', 'rag_top_k': 5, 'use_llm_refine': False}, 'training': {'batch_size': 32, 'max_epochs': 10, 'learning_rate': '1e-3'}, 'evaluation': {'metrics': ['accuracy', 'macro_f1', 'auc_ovr']}}
#
# === Configuration Variables ===
#
# [DATASET]
#   DATASET_N_CLASSES: 25
#   DATASET_N_SAMPLES_PER_CLASS: 100
#   DATASET_SPLIT_TYPE: test
#
# [EVALUATION]
#   EVALUATION_METRICS: ['accuracy', 'macro_f1', 'auc_ovr']
#
# [GENERAL]
#   GENERAL_RUN_NAME: experiment_with_05_classes
#   GENERAL_SEED: 42
#
# [MODEL]
#   MODEL_CLASSIFIER: linear_svm
#   MODEL_EMBEDDING_BACKEND: sbert
#   MODEL_OPENAI_MODEL_NAME: text-embedding-3-small
#   MODEL_RAG_TOP_K: 5
#   MODEL_SBERT_MODEL_NAME: sentence-transformers/all-MiniLM-L12-v2
#   MODEL_USE_LLM_REFINE: False
#
# [PATHS]
#   PATHS_DATA_EXPLORATION_DIR: /home/marcmaceira/projects/reuters-rag-classifier_clean_v2/output/experiment_with_05_classes/data_exploration
#   PATHS_EMBEDDINGS_DIR: /home/marcmaceira/projects/reuters-rag-classifier_clean_v2/output/experiment_with_05_classes/embeddings
#   PATHS_MODELS_DIR: /home/marcmaceira/projects/reuters-rag-classifier_clean_v2/output/experiment_with_05_classes/models
#   PATHS_RESULTS_DIR: /home/marcmaceira/projects/reuters-rag-classifier_clean_v2/output/experiment_with_05_classes/results
#
# [TRAINING]
#   TRAINING_BATCH_SIZE: 32
#   TRAINING_LEARNING_RATE: 1e-3
#   TRAINING_MAX_EPOCHS: 10
#
# === Environment Variables ===
# N_CLASSES: 25
#
# === Creating Directories ===
# Created directory: /home/marcmaceira/projects/reuters-rag-classifier_clean_v2/output/experiment_with_05_classes/data_exploration
# Created directory: /home/marcmaceira/projects/reuters-rag-classifier_clean_v2/output/experiment_with_05_classes/embeddings
# Created directory: /home/marcmaceira/projects/reuters-rag-classifier_clean_v2/output/experiment_with_05_classes/models
# Created directory: /home/marcmaceira/projects/reuters-rag-classifier_clean_v2/output/experiment_with_05_classes/results

# %% [markdown]
# # Reuters News Topic Classification - Data Loading
#
# This notebook handles the initial data loading and preprocessing for the Reuters news topic classification task. We'll be using the Reuters-21578 corpus, a classic dataset of Reuters newswire articles labeled with economic topics.
#
# ## Dataset Overview
#
# The Reuters-21578 corpus is a collection of 10,788 Reuters newswire articles that have been labeled with economic topics. Key features:
#
# * Open license - freely redistributable for research/commercial use
# * Rich, domain-specific text - financial and commodities news
# * Benchmark pedigree - allows comparison against decades of literature
#
# ## Setup and Imports

# %%
import logging
import warnings
from src.datasets.dataset import get_dataset

warnings.filterwarnings('ignore')
logging.basicConfig(level=logging.INFO, format='%(levelname)s | %(message)s')

# %% [markdown]
# ## Load Dataset
#
# We'll load the top 10 topics for clarity in our classification task.

# %%
# Load dataset
# X_train, y_train, _, _, _ = get_dataset(split_type="standard", n_classes=N_CLASSES)
X_train, y_train, X_test, y_test, classes = get_dataset(
    split_type=DATASET_SPLIT_TYPE,
    n_classes=N_CLASSES,
    n_samples_per_class=N_SAMPLES_PER_CLASS,
)

print(f"Loaded {len(X_train)} training documents with {N_CLASSES} classes")
# Out:
# INFO | Loading Reuters dataset with configuration:
# INFO |   - Split type: test
# INFO |   - Number of classes: 25
# INFO |   - Samples per class: 100
# INFO |   - Random seed: None
# INFO | Loading small test dataset with 100 samples per class across 25 classes
# INFO | Selected classes: earn, acq, crude, interest, money-fx, trade, grain, corn, dlr, money-supply, ship, coffee, sugar, gold, bop, gnp, cpi, cocoa, carcass, oilseed, copper, alum, reserves, jobs, barley
# INFO |   - Class 'earn': 70 train, 30 test
# INFO |   - Class 'acq': 70 train, 30 test
# INFO |   - Class 'crude': 70 train, 30 test
# INFO |   - Class 'interest': 70 train, 30 test
# INFO |   - Class 'money-fx': 70 train, 30 test
# INFO |   - Class 'trade': 70 train, 30 test
# INFO |   - Class 'grain': 70 train, 30 test
# INFO |   - Class 'corn': 70 train, 30 test
# INFO |   - Class 'dlr': 70 train, 30 test
# INFO |   - Class 'money-supply': 70 train, 30 test
# INFO |   - Class 'ship': 70 train, 30 test
# INFO |   - Class 'coffee': 70 train, 30 test
# INFO |   - Class 'sugar': 70 train, 30 test
# INFO |   - Class 'gold': 70 train, 30 test
# INFO |   - Class 'bop': 70 train, 30 test
# INFO |   - Class 'gnp': 70 train, 30 test
# INFO |   - Class 'cpi': 63 train, 28 test
# INFO |   - Class 'cocoa': 50 train, 22 test
# INFO |   - Class 'carcass': 46 train, 20 test
# INFO |   - Class 'oilseed': 43 train, 19 test
# INFO |   - Class 'copper': 42 train, 18 test
# INFO |   - Class 'alum': 39 train, 18 test
# INFO |   - Class 'reserves': 37 train, 16 test
# INFO |   - Class 'jobs': 36 train, 16 test
# INFO |   - Class 'barley': 35 train, 16 test
# Loaded 1511 training documents with 25 classes

# %% [markdown]
# ## Data Exploration
#
# Let's examine the distribution of classes and article lengths to understand our dataset better.

# %%
from src.exploration import class_frequency, length_distribution
import pandas as pd


# Imbalance plot
class_frequency(y_train, top_n=20)

# Article length distribution
stats = length_distribution(X_train)
print(f"Mean length: {stats['stats']['mean']:.1f} tokens, median: {stats['stats']['median']}")
# Out:
# Mean length: 173.7 tokens, median: 114.0
